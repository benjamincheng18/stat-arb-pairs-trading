# %%
import sys
sys.path.append('..')

from src.data_loader import load_prices, get_ticker_universe, get_all_tickers

prices, universe = load_prices()
all_tickers = get_all_tickers(universe)
dropped = set(all_tickers) - set(prices.columns)
print("Dropped:", dropped)
# Out:
# /Users/for_everyoung10/Documents/stat-arb-pairs-trading/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Tickers after cleaning: 67
# Dropped: {'7769.TW'}

# %%
import sys
sys.path.append('..')
from src.data_loader import load_prices
from src.cointegration import screen_all_pairs, apply_fdr_correction

prices, universe = load_prices()
results = screen_all_pairs(prices)
results = apply_fdr_correction(results)

print(results["cointegrated"].value_counts())
print(results[results["cointegrated"]])
# Out:
# /Users/for_everyoung10/Documents/stat-arb-pairs-trading/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Tickers after cleaning: 67
# cointegrated
# False    2161
# True       50
# Name: count, dtype: int64
#         stock1    stock2   pvalue_1on2    hr_1on2   pvalue_2on1    hr_2on1  \
# 152    2303.TW   2492.TW  9.148512e-05   0.375660  1.169544e-03   2.150728
# 157    2303.TW   3037.TW  1.856165e-05   0.070816  3.105299e-07  11.513727
# 161    2303.TW   3189.TW  1.178451e-03   0.114358  1.289021e-03   7.065164
# 303    2313.TW  6274.TWO  1.720208e-04   0.195711  3.352489e-05   4.112758
# 387    2327.TW   2360.TW  3.378233e-04   0.159754  6.328702e-06   5.314702
# 405    2327.TW  3081.TWO  1.903671e-03   0.122114  9.403060e-07   6.176004
# ...
